# %% [markdown]
# <a href="https://colab.research.google.com/github/Sanchit525/ETF---Smart-Portfolio/blob/Test/ETF_Smart_Portfolio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import yfinance as yf
from datetime import date, timedelta
from dateutil.relativedelta import relativedelta
import pandas as pd
from pathlib import Path
import numpy as np

# %% [markdown]
# **Extracting tickers of all the etfs**

# %%
etf_database = pd.read_csv("/content/MW-ETF-27-Jan-2026.csv")
etf_database.columns
# Out:
# Index(['SYMBOL \n', 'UNDERLYING ASSET \n', 'OPEN \n', 'HIGH \n', 'LOW \n',
#        'PREV. CLOSE \n', 'LTP \n', 'INDICATIVE CLOSE \n', 'CHNG \n',
#        '%CHNG \n', 'VOLUME \n', 'VALUE \n (₹ Crores)', 'NAV \n', '52W H \n',
#        '52W L \n', '30D  %CHNG \n', '365 D   %CHNG \n'],
#       dtype='object')

# %%
tickers = etf_database["SYMBOL \n"].to_list()
tickers.insert(0,'NIFTY 50')
print(tickers)
# Out:
# ['NIFTY 50', 'TATSILV', 'HDFCSILVER', 'SILVERAG', 'SILVERBETA', 'SBISILVER', 'AXISILVER', 'SILVERIETF', 'GROWWSLVR', 'SILVERCASE', 'SILVERBEES', 'SILVERADD', 'MOSILVER', 'SILVER', 'SILVER1', 'SILVERBND', 'ESILVER', 'SILVER360', 'HDFCMOMENT', 'EGOLD', 'GROWWN200', 'METALIETF', 'TWCGOLDETF', 'GOLDBND', 'GOLDETF', 'GROWWMETAL', 'CHOICEGOLD', 'TATAGOLD', 'HDFCPVTBAN', 'GROWWPOWER', 'GOLDIETF', 'GOLDBEES', 'IVZINGOLD', 'GROWWSC250', 'EVIETF', 'METAL', 'AXISGOLD', 'HDFCNEXT50', 'SETFGOLD', 'GOLDCASE', 'HDFCNIF100', 'GROWWNET', 'HDFCGOLD', 'HDFCQUAL', 'GOLD1', 'BSLGOLDETF', 'GOLDBETA', 'GROWWGOLD', 'QGOLDHALF', 'MOMENTUM30', 'GOLDADD', 'AONETMMQ50', 'AONEGOLD', 'GOLD360', 'MOGOLD', 'MODEFENCE', 'MOTOUR', 'AXISVALUE', 'GROWWDEFNC', 'PSUBNKBEES', 'COMMOIETF', 'BBNPPGOLD', 'HDFCPSUBK', 'SML100CASE', 'BANKPSU', 'SBIBPB', 'PSUBNKIETF', 'LICMFGOLD', 'PSUBANK', 'MANUFGBEES', 'MOVALUE', 'GROWWCAPM', 'BANKADD', 'CPSEETF', 'ELM250', 'BANKETF', 'ICICIB22', 'PSUBANKADD', 'MOCAPITAL', 'BANKIETF', 'HDFCNIFBAN', 'BBNPNBETF', 'TOP10ADD', 'BANKBETA', 'QUAL30IETF', 'DIVIDEND', 'BANKBEES', 'NIFTY100EW', 'BANKBETF', 'SETFNIFBK', 'MID150CASE', 'AXISBNKETF', 'ECAPINSURE', 'MOPSE', 'SBIETFIT', 'UNIONGOLD', 'NV20', 'NIF100BEES', 'PVTBANIETF', 'ITBEES', 'MOENERGY', 'BFSI', 'MONQ50', 'OILIETF', 'EMULTIMQ', 'ABSLPSE', 'BANKNIFTY1', 'SBIETFPB', 'ABSLBANETF', 'MONIFTY500', 'ITIETF', 'MOMOMENTUM', 'GROWWRAIL', 'MIDSMALL', 'NIFTYCASE', 'GROWWMC150', 'MID150', 'TOP100CASE', 'BSLNIFTY', 'PVTBANKADD', 'NEXT30ADD', 'AXISHCETF', 'ITETF', 'MOREALTY', 'MOMIDMTM', 'MAFANG', 'NEXT50', 'SBIETFQLTY', 'MOHEALTH', 'ENERGY', 'NV20BEES', 'MOM100', 'INFRABEES', 'MON50EQUAL', 'ABSLNN50ET', 'EQUAL200', 'MOINFRA', 'ITBETA', 'MIDCAPIETF', 'MULTICAP', 'MIDCAPBETA', 'JUNIORBEES', 'EQUAL50ADD', 'EBANKNIFTY', 'CHEMICAL', 'LICNFNHGP', 'MOSMALL250', 'HDFCSML250', 'SENSEXBETA', 'MID150BEES', 'HDFCNIFTY', 'MSCIINDIA', 'NV20IETF', 'INFRAIETF', 'ITADD', 'NIFTYBEES', 'MONIFTY100', 'MIDCAPETF', 'HDFCNIFIT', 'AXISNIFTY', 'ENIFTY', 'MONEXT50', 'AONENIFTY', 'MOM50', 'NEXT50IETF', 'MOM30IETF', 'NIFTYBETF', 'SMALLCAP', 'MIDCAP', 'NIFTYADD', 'IT', 'MOMENTUM', 'NIFTYIETF', 'HDFCMID150', 'NIFTYBETA', 'QNIFTY', 'NIFTYETF', 'GROWWNIFTY', 'SMALL250', 'NIFTY1', 'SETFNIF50', 'FLEXIADD', 'MIDSELIETF', 'MOALPHA50', 'HDFCVALUE', 'BSE500IETF', 'MOQUALITY', 'MOSERVICE', 'ALPHAETF', 'SNXT30BEES', 'SENSEXIETF', 'SBINEQWETF', 'AXISTECETF', 'EQUAL50', 'GROWWLOVOL', 'MIDCAPADD', 'SHARIABEES', 'GROWWRLTY', 'SMALLADD', 'AXSENSEX', 'LICNMID100', 'ESG', 'AONETOTAL', 'ESENSEX', 'SENSEXETF', 'MSCIADD', 'ALPL30IETF', 'NETF', 'MAKEINDIA', 'GROWWMOM50', 'BBETF0432', 'TNIDETF', 'BSLSENETFG', 'MOLOWVOL', 'SENSEXADD', 'MOMENTUM50', 'NEXT50BETA', 'GROWWCHEM', 'IDFNIFTYET', 'NPBET', 'NIFTYQLITY', 'NEXT50ETF', 'GILT10BETA', 'ABGSEC', 'LICNETFN50', 'SETFNN50', 'MNC', 'MOMNC', 'MAHKTECH', 'MIDQ50ADD', 'TOP20', 'NIF100IETF', 'EBBETF0433', 'SELECTIPO', 'LOWVOLIETF', 'PHARMABEES', 'NEXT50ADD', 'ALPHA', 'GROWWEV', 'HNGSNGBEES', 'LICNETFGSC', 'HDFCSENSEX', 'GILT5YBEES', 'TOP15IETF', 'HEALTHIETF', 'MOIPO', 'FMCGIETF', 'LOWVOL', 'LIQUID1', 'LIQUIDCASE', 'GROWWLIQID', 'ELIQUID', 'LIQUIDADD', 'HDFCLIQUID', 'LIQUIDBETF', 'SBILIQETF', 'LIQGRWBEES', 'CASHIETF', 'LIQUIDSHRI', 'LIQUIDPLUS', 'AONELIQUID', 'IVZINNIFTY', 'LIQUIDETF', 'LIQUIDSBI', 'ABSLLIQUID', 'LIQUIDIETF', 'LICNETFSEN', 'LIQUIDBEES', 'LIQUID', 'EBBETF0431', 'LTGILTCASE', 'MOGSEC', 'LTGILTBEES', 'EVINDIA', 'TECH', 'HDFCLOWVOL', 'EBBETF0430', 'GSEC10YEAR', 'GSEC10IETF', 'GROWWNXT50', 'GSEC10ABSL', 'HEALTHY', 'AXISBPSETF', 'SETF10GILT', 'CONSUMIETF', 'INTERNET', 'GSEC5IETF', 'CONSUMER', 'HEALTHADD', 'MON100', 'CONSUMBEES', 'DIVOPPBEES', 'HDFCGROWTH', 'SDL26BEES', 'GILT5BETA', 'VAL30IETF', 'MOMGF', 'AUTOBEES', 'HDFCBSE500', 'AUTOIETF', 'SBIETFCON', 'QUALITY30', 'AXISCETF', 'CONS', 'MASPTOP50', 'LOWVOL1', 'FINIETF', 'SNXT50BETA']

# %%
# When we have to update excel file
tickers = ['NIFTY 50', 'TATSILV', 'HDFCSILVER', 'SILVERAG', 'SILVERBETA', 'SBISILVER', 'AXISILVER', 'SILVERIETF', 'GROWWSLVR', 'SILVERCASE', 'SILVERBEES', 'SILVERADD', 'MOSILVER', 'SILVER', 'SILVER1', 'SILVERBND', 'ESILVER', 'SILVER360', 'HDFCMOMENT', 'EGOLD', 'GROWWN200', 'METALIETF', 'TWCGOLDETF', 'GOLDBND', 'GOLDETF', 'GROWWMETAL', 'CHOICEGOLD', 'TATAGOLD', 'HDFCPVTBAN', 'GROWWPOWER', 'GOLDIETF', 'GOLDBEES', 'IVZINGOLD', 'GROWWSC250', 'EVIETF', 'METAL', 'AXISGOLD', 'HDFCNEXT50', 'SETFGOLD', 'GOLDCASE', 'HDFCNIF100', 'GROWWNET', 'HDFCGOLD', 'HDFCQUAL', 'GOLD1', 'BSLGOLDETF', 'GOLDBETA', 'GROWWGOLD', 'QGOLDHALF', 'MOMENTUM30', 'GOLDADD', 'AONETMMQ50', 'AONEGOLD', 'GOLD360', 'MOGOLD', 'MODEFENCE', 'MOTOUR', 'AXISVALUE', 'GROWWDEFNC', 'PSUBNKBEES', 'COMMOIETF', 'BBNPPGOLD', 'HDFCPSUBK', 'SML100CASE', 'BANKPSU', 'SBIBPB', 'PSUBNKIETF', 'LICMFGOLD', 'PSUBANK', 'MANUFGBEES', 'MOVALUE', 'GROWWCAPM', 'BANKADD', 'CPSEETF', 'ELM250', 'BANKETF', 'ICICIB22', 'PSUBANKADD', 'MOCAPITAL', 'BANKIETF', 'HDFCNIFBAN', 'BBNPNBETF', 'TOP10ADD', 'BANKBETA', 'QUAL30IETF', 'DIVIDEND', 'BANKBEES', 'NIFTY100EW', 'BANKBETF', 'SETFNIFBK', 'MID150CASE', 'AXISBNKETF', 'ECAPINSURE', 'MOPSE', 'SBIETFIT', 'UNIONGOLD', 'NV20', 'NIF100BEES', 'PVTBANIETF', 'ITBEES', 'MOENERGY', 'BFSI', 'MONQ50', 'OILIETF', 'EMULTIMQ', 'ABSLPSE', 'BANKNIFTY1', 'SBIETFPB', 'ABSLBANETF', 'MONIFTY500', 'ITIETF', 'MOMOMENTUM', 'GROWWRAIL', 'MIDSMALL', 'NIFTYCASE', 'GROWWMC150', 'MID150', 'TOP100CASE', 'BSLNIFTY', 'PVTBANKADD', 'NEXT30ADD', 'AXISHCETF', 'ITETF', 'MOREALTY', 'MOMIDMTM', 'MAFANG', 'NEXT50', 'SBIETFQLTY', 'MOHEALTH', 'ENERGY', 'NV20BEES', 'MOM100', 'INFRABEES', 'MON50EQUAL', 'ABSLNN50ET', 'EQUAL200', 'MOINFRA', 'ITBETA', 'MIDCAPIETF', 'MULTICAP', 'MIDCAPBETA', 'JUNIORBEES', 'EQUAL50ADD', 'EBANKNIFTY', 'CHEMICAL', 'LICNFNHGP', 'MOSMALL250', 'HDFCSML250', 'SENSEXBETA', 'MID150BEES', 'HDFCNIFTY', 'MSCIINDIA', 'NV20IETF', 'INFRAIETF', 'ITADD', 'NIFTYBEES', 'MONIFTY100', 'MIDCAPETF', 'HDFCNIFIT', 'AXISNIFTY', 'ENIFTY', 'MONEXT50', 'AONENIFTY', 'MOM50', 'NEXT50IETF', 'MOM30IETF', 'NIFTYBETF', 'SMALLCAP', 'MIDCAP', 'NIFTYADD', 'IT', 'MOMENTUM', 'NIFTYIETF', 'HDFCMID150', 'NIFTYBETA', 'QNIFTY', 'NIFTYETF', 'GROWWNIFTY', 'SMALL250', 'NIFTY1', 'SETFNIF50', 'FLEXIADD', 'MIDSELIETF', 'MOALPHA50', 'HDFCVALUE', 'BSE500IETF', 'MOQUALITY', 'MOSERVICE', 'ALPHAETF', 'SNXT30BEES', 'SENSEXIETF', 'SBINEQWETF', 'AXISTECETF', 'EQUAL50', 'GROWWLOVOL', 'MIDCAPADD', 'SHARIABEES', 'GROWWRLTY', 'SMALLADD', 'AXSENSEX', 'LICNMID100', 'ESG', 'AONETOTAL', 'ESENSEX', 'SENSEXETF', 'MSCIADD', 'ALPL30IETF', 'NETF', 'MAKEINDIA', 'GROWWMOM50', 'BBETF0432', 'TNIDETF', 'BSLSENETFG', 'MOLOWVOL', 'SENSEXADD', 'MOMENTUM50', 'NEXT50BETA', 'GROWWCHEM', 'IDFNIFTYET', 'NPBET', 'NIFTYQLITY', 'NEXT50ETF', 'GILT10BETA', 'ABGSEC', 'LICNETFN50', 'SETFNN50', 'MNC', 'MOMNC', 'MAHKTECH', 'MIDQ50ADD', 'TOP20', 'NIF100IETF', 'EBBETF0433', 'SELECTIPO', 'LOWVOLIETF', 'PHARMABEES', 'NEXT50ADD', 'ALPHA', 'GROWWEV', 'HNGSNGBEES', 'LICNETFGSC', 'HDFCSENSEX', 'GILT5YBEES', 'TOP15IETF', 'HEALTHIETF', 'MOIPO', 'FMCGIETF', 'LOWVOL', 'LIQUID1', 'LIQUIDCASE', 'GROWWLIQID', 'ELIQUID', 'LIQUIDADD', 'HDFCLIQUID', 'LIQUIDBETF', 'SBILIQETF', 'LIQGRWBEES', 'CASHIETF', 'LIQUIDSHRI', 'LIQUIDPLUS', 'AONELIQUID', 'IVZINNIFTY', 'LIQUIDETF', 'LIQUIDSBI', 'ABSLLIQUID', 'LIQUIDIETF', 'LICNETFSEN', 'LIQUIDBEES', 'LIQUID', 'EBBETF0431', 'LTGILTCASE', 'MOGSEC', 'LTGILTBEES', 'EVINDIA', 'TECH', 'HDFCLOWVOL', 'EBBETF0430', 'GSEC10YEAR', 'GSEC10IETF', 'GROWWNXT50', 'GSEC10ABSL', 'HEALTHY', 'AXISBPSETF', 'SETF10GILT', 'CONSUMIETF', 'INTERNET', 'GSEC5IETF', 'CONSUMER', 'HEALTHADD', 'MON100', 'CONSUMBEES', 'DIVOPPBEES', 'HDFCGROWTH', 'SDL26BEES', 'GILT5BETA', 'VAL30IETF', 'MOMGF', 'AUTOBEES', 'HDFCBSE500', 'AUTOIETF', 'SBIETFCON', 'QUALITY30', 'AXISCETF', 'CONS', 'MASPTOP50', 'LOWVOL1', 'FINIETF', 'SNXT50BETA']

# %%
enddate = date.today()
startdate = enddate - relativedelta(years=5)

# %%
print(enddate)
print(startdate)
# Out:
# 2026-01-30
# 2021-01-30

# %% [markdown]
# **Downloading NIFTY 50 data**

# %%
nse_index = yf.download("^NSEI",start=startdate,end=enddate,auto_adjust=False,progress=False)

# %%
nse_index.columns
# Out:
# MultiIndex([('Adj Close', '^NSEI'),
#             (    'Close', '^NSEI'),
#             (     'High', '^NSEI'),
#             (      'Low', '^NSEI'),
#             (     'Open', '^NSEI'),
#             (   'Volume', '^NSEI')],
#            names=['Price', 'Ticker'])

# %%
nse_index.reset_index(inplace = True)
nse_index.columns = nse_index.columns.get_level_values(0)

# %%
nse_index.head()
# Out:
# Price       Date     Adj Close  ...          Open  Volume
# 0     2021-01-27  13967.500000  ...  14237.950195  660700
# 1     2021-01-28  13817.549805  ...  13810.400391  637900
# 2     2021-01-29  13634.599609  ...  13946.599609  753200
# 3     2021-02-01  14281.200195  ...  13758.599609  870500
# 4     2021-02-02  14647.849609  ...  14481.099609  915000
#
# [5 rows x 7 columns]

# %% [markdown]
# **Downloading all ETFs data**

# %%
with pd.ExcelWriter("etf_data.xlsx", engine="openpyxl") as writer:
    for tick in tickers:
        print(f"Downloading {tick}.NS")

        df = yf.download(
            f"{tick}.NS",
            start=startdate,
            end=enddate,
            auto_adjust=False,
            progress=False
        )

        if df.empty:
            print(f"No data for {tick}")
            continue

        df.reset_index(inplace=True)
        df.columns = df.columns.get_level_values(0)
        df.to_excel(
            writer,
            sheet_name=tick,
            index=False
        )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-725164543.py in <cell line: 0>()
#       1 with pd.ExcelWriter("etf_data.xlsx", engine="openpyxl") as writer:
# ----> 2     for tick in tickers:
#       3         print(f"Downloading {tick}.NS")
#
# NameError: name 'tickers' is not defined
#
# During handling of the above exception, another exception occurred:
#
# IndexError                                Traceback (most recent call last)
# /tmp/ipython-input-725164543.py in <cell line: 0>()
# ----> 1 with pd.ExcelWriter("etf_data.xlsx", engine="openpyxl") as writer:
#       2     for tick in tickers:
#       3         print(f"Downloading {tick}.NS")
#       4
#       5         df = yf.download(
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/excel/_base.py in __exit__(self, exc_type, exc_value, traceback)
#    1351         traceback: TracebackType | None,
#    1352     ) -> None:
# -> 1353         self.close()
#    1354
#    1355     def close(self) -> None:
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/excel/_base.py in close(self)
#    1355     def close(self) -> None:
#    1356         """synonym for save, to make it more file-like"""
# -> 1357         self._save()
#    1358         self._handles.close()
#    1359
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/excel/_openpyxl.py in _save(self)
#     108         Save workbook to disk.
#     109         """
# --> 110         self.book.save(self._handles.handle)
#     111         if "r+" in self._mode and not isinstance(self._handles.handle, mmap.mmap):
#     112             # truncate file to the written content
#
# /usr/local/lib/python3.12/dist-packages/openpyxl/workbook/workbook.py in save(self, filename)
#     384         if self.write_only and not self.worksheets:
#     385             self.create_sheet()
# --> 386         save_workbook(self, filename)
#     387
#     388
#
# /usr/local/lib/python3.12/dist-packages/openpyxl/writer/excel.py in save_workbook(workbook, filename)
#     292     workbook.properties.modified = datetime.datetime.now(tz=datetime.timezone.utc).replace(tzinfo=None)
#     293     writer = ExcelWriter(workbook, archive)
# --> 294     writer.save()
#     295     return True
#
# /usr/local/lib/python3.12/dist-packages/openpyxl/writer/excel.py in save(self)
#     273     def save(self):
#     274         """Write data into the archive."""
# --> 275         self.write_data()
#     276         self._archive.close()
#     277
#
# /usr/local/lib/python3.12/dist-packages/openpyxl/writer/excel.py in write_data(self)
#      87         writer = WorkbookWriter(self.workbook)
#      88         archive.writestr(ARC_ROOT_RELS, writer.write_root_rels())
# ---> 89         archive.writestr(ARC_WORKBOOK, writer.write())
#      90         archive.writestr(ARC_WORKBOOK_RELS, writer.write_rels())
#      91
#
# /usr/local/lib/python3.12/dist-packages/openpyxl/workbook/_writer.py in write(self)
#     148         self.write_names()
#     149         self.write_pivots()
# --> 150         self.write_views()
#     151         self.write_refs()
#     152
#
# /usr/local/lib/python3.12/dist-packages/openpyxl/workbook/_writer.py in write_views(self)
#     135
#     136     def write_views(self):
# --> 137         active = get_active_sheet(self.wb)
#     138         if self.wb.views:
#     139             self.wb.views[0].activeTab = active
#
# /usr/local/lib/python3.12/dist-packages/openpyxl/workbook/_writer.py in get_active_sheet(wb)
#      33     visible_sheets = [idx for idx, sheet in enumerate(wb._sheets) if sheet.sheet_state == "visible"]
#      34     if not visible_sheets:
# ---> 35         raise IndexError("At least one sheet must be visible")
#      36
#      37     idx = wb._active_sheet_index
#
# IndexError: At least one sheet must be visible

# %%
nse_index.to_excel("/content/nse_index_data.xlsx",index = False)

# %% [markdown]
# **Framework to append new data daily**

# %%
file_path = '/content/etf_data.xlsx'

# %%
def fetch_new_data(ticker, start_date):
  if ticker == "NIFTY 50":
    df = yf.download("^NSEI",start = start_date,progress = False)
  else:
    df = yf.download(
        f"{ticker}.NS",
        start=start_date,
        progress=False
    )

  if df.empty:
      return df

  df.reset_index(inplace=True)
  df.columns = df.columns.get_level_values(0)

  return df

# %%
def update_excel():
    file_exists = Path(file_path).exists()

    # Open writer in append mode
    with pd.ExcelWriter(
        file_path,
        engine="openpyxl",
        mode="a",
        if_sheet_exists="overlay"
    ) as writer:

        for ticker in tickers:
            print(f"Updating {ticker}")

            try:
                existing = pd.read_excel(file_path, sheet_name=ticker)
                last_date = pd.to_datetime(existing["Date"]).max()
                start_date = last_date + timedelta(days=1)
            except Exception:
                # Sheet doesn't exist
                existing = None
                start_date = last_date + timedelta(days=1)

            #Fetch new data
            new_data = fetch_new_data(ticker, start_date)

            if new_data.empty:
                print(f"No new data for {ticker}")
                continue

            #Combine & de-duplicate
            if existing is not None:
                combined = pd.concat([existing, new_data], ignore_index=True)
                combined.drop_duplicates(subset=["Date"], inplace=True)
            else:
                combined = new_data

            #Write back to same sheet
            combined.to_excel(
                writer,
                sheet_name=ticker,
                index=False
            )

    print("Excel update complete")

# %%
update_excel()
# Out:
# Updating NIFTY 50
# /tmp/ipython-input-2581299091.py:3: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.
# /tmp/ipython-input-2581299091.py:5: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(
# Updating SELECTIPO
# /tmp/ipython-input-2581299091.py:5: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(
# Updating LOWVOLIETF
# /tmp/ipython-input-2581299091.py:5: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(
# Updating PHARMABEES
# /tmp/ipython-input-2581299091.py:5: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(
# Updating NEXT50ADD
# /tmp/ipython-input-2581299091.py:5: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(
# Updating ALPHA
# /tmp/ipython-input-2581299091.py:5: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(
# Updating GROWWEV
# /tmp/ipython-input-2581299091.py:5: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(
# Updating HNGSNGBEES
# /tmp/ipython-input-2581299091.py:5: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(
# Updating LICNETFGSC
# /tmp/ipython-input-2581299091.py:5: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(
# Updating HDFCSENSEX
# /tmp/ipython-input-2581299091.py:5: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(
# Updating GILT5YBEES
# /tmp/ipython-input-2581299091.py:5: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(
# Updating TOP15IETF
# /tmp/ipython-input-2581299091.py:5: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(
# Updating HEALTHIETF
# /tmp/ipython-input-2581299091.py:5: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(
# Updating MOIPO
# /tmp/ipython-input-2581299091.py:5: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(
# Updating FMCGIETF
# /tmp/ipython-input-2581299091.py:5: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(
# Updating LOWVOL
# /tmp/ipython-input-2581299091.py:5: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(
# Updating LIQUID1
# /tmp/ipython-input-2581299091.py:5: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(
# Updating LIQUIDCASE
# /tmp/ipython-input-2581299091.py:5: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(
# Updating GROWWLIQID
# /tmp/ipython-input-2581299091.py:5: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(
# Updating ELIQUID
# /tmp/ipython-input-2581299091.py:5: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(
# Updating LIQUIDADD
# /tmp/ipython-input-2581299091.py:5: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(
# Updating HDFCLIQUID
# /tmp/ipython-input-2581299091.py:5: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(
# Updating LIQUIDBETF
# /tmp/ipython-input-2581299091.py:5: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(
# Updating SBILIQETF
# /tmp/ipython-input-2581299091.py:5: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(
# Updating LIQGRWBEES
# /tmp/ipython-input-2581299091.py:5: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(
# Updating CASHIETF
# /tmp/ipython-input-2581299091.py:5: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(
# Updating LIQUIDSHRI
# /tmp/ipython-input-2581299091.py:5: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(
# Updating LIQUIDPLUS
# /tmp/ipython-input-2581299091.py:5: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(
# Updating AONELIQUID
# /tmp/ipython-input-2581299091.py:5: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(
# Updating IVZINNIFTY
# /tmp/ipython-input-2581299091.py:5: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(
# Updating LIQUIDETF
# /tmp/ipython-input-2581299091.py:5: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(
# Updating LIQUIDSBI
# /tmp/ipython-input-2581299091.py:5: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(
# Updating ABSLLIQUID
# /tmp/ipython-input-2581299091.py:5: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(
# Updating LIQUIDIETF
# /tmp/ipython-input-2581299091.py:5: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(
# Updating LICNETFSEN
# /tmp/ipython-input-2581299091.py:5: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(
# Updating LIQUIDBEES
# /tmp/ipython-input-2581299091.py:5: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(
# Updating LIQUID
# /tmp/ipython-input-2581299091.py:5: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(
# Updating EBBETF0431
# /tmp/ipython-input-2581299091.py:5: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(
# Updating LTGILTCASE
# /tmp/ipython-input-2581299091.py:5: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(
# Updating MOGSEC
# /tmp/ipython-input-2581299091.py:5: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(
# Updating LTGILTBEES
# /tmp/ipython-input-2581299091.py:5: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(
# Updating EVINDIA
# /tmp/ipython-input-2581299091.py:5: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(
# Updating TECH
# /tmp/ipython-input-2581299091.py:5: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(
# Updating HDFCLOWVOL
# /tmp/ipython-input-2581299091.py:5: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(
# Updating EBBETF0430
# /tmp/ipython-input-2581299091.py:5: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(
# Updating GSEC10YEAR
# /tmp/ipython-input-2581299091.py:5: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(
# Updating GSEC10IETF
# /tmp/ipython-input-2581299091.py:5: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(
# Updating GROWWNXT50
# /tmp/ipython-input-2581299091.py:5: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(
# Updating GSEC10ABSL
# /tmp/ipython-input-2581299091.py:5: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(
# Updating HEALTHY
# /tmp/ipython-input-2581299091.py:5: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(
# Updating AXISBPSETF
# /tmp/ipython-input-2581299091.py:5: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(
# Updating SETF10GILT
# /tmp/ipython-input-2581299091.py:5: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(
# Updating CONSUMIETF
# /tmp/ipython-input-2581299091.py:5: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(
# Updating INTERNET
# /tmp/ipython-input-2581299091.py:5: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(
# Updating GSEC5IETF
# /tmp/ipython-input-2581299091.py:5: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(
# Updating CONSUMER
# /tmp/ipython-input-2581299091.py:5: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(
# Updating HEALTHADD
# /tmp/ipython-input-2581299091.py:5: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(
# Updating MON100
# /tmp/ipython-input-2581299091.py:5: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(
# Updating CONSUMBEES
# /tmp/ipython-input-2581299091.py:5: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(
# Updating DIVOPPBEES
# /tmp/ipython-input-2581299091.py:5: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(
# Updating HDFCGROWTH
# /tmp/ipython-input-2581299091.py:5: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(
# Updating SDL26BEES
# /tmp/ipython-input-2581299091.py:5: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(
# Updating GILT5BETA
# /tmp/ipython-input-2581299091.py:5: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(
# Updating VAL30IETF
# /tmp/ipython-input-2581299091.py:5: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(
# Updating MOMGF
# /tmp/ipython-input-2581299091.py:5: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(
# Updating AUTOBEES
# /tmp/ipython-input-2581299091.py:5: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(
# Updating HDFCBSE500
# /tmp/ipython-input-2581299091.py:5: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(
# Updating AUTOIETF
# /tmp/ipython-input-2581299091.py:5: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(
# Updating SBIETFCON
# /tmp/ipython-input-2581299091.py:5: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(
# Updating QUALITY30
# /tmp/ipython-input-2581299091.py:5: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(
# Updating AXISCETF
# /tmp/ipython-input-2581299091.py:5: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(
# Updating CONS
# /tmp/ipython-input-2581299091.py:5: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(
# Updating MASPTOP50
# /tmp/ipython-input-2581299091.py:5: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(
# Updating LOWVOL1
# /tmp/ipython-input-2581299091.py:5: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(
# Updating FINIETF
# /tmp/ipython-input-2581299091.py:5: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(
# Updating SNXT50BETA
# /tmp/ipython-input-2581299091.py:5: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(
# Excel update complete

# %% [markdown]
# **ETFs Filtering**

# %%
etf_metric = pd.DataFrame(index = tickers)
etf_metric = etf_metric.drop(index='NIFTY 50',axis=0)

# %%
def universe_eligibility(
    data,
    as_of_date,
    atv_threshold=5e7,
    min_years=2
):

    # Ensure datetime
    data = data.copy()
    data['Date'] = pd.to_datetime(data['Date'])

    # Use only data up to as_of_date
    data = data[data['Date'] <= as_of_date]

    # Safeguard
    if data.empty:
        return False

    # Average Trading Value
    atv = (data['Close'] * data['Volume']).mean()

    # History requirement
    first_date = data['Date'].min()
    history_ok = (as_of_date - first_date) >= timedelta(days=365 * min_years)

    return (atv >= atv_threshold) and history_ok

# %%
def portfolio_eligibility(
    data,
    as_of_date,
    ma_window=200,
    lookback_days=126
):
    """
    Portfolio eligibility as of a given date.
    """

    data = data.copy()
    data['Date'] = pd.to_datetime(data['Date'])

    # Use only data up to as_of_date
    data = data[data['Date'] <= as_of_date]

    # Not enough history
    if len(data) < max(ma_window, lookback_days):
        return False

    # Moving average
    data['200MA'] = data['Close'].rolling(window=ma_window).mean()

    latest_close = data.iloc[-1]['Close']
    latest_200ma = data.iloc[-1]['200MA']

    ma_condition = latest_close > latest_200ma

    # 6-month return
    past_price = data.iloc[-lookback_days]['Close']
    six_month_return = (latest_close / past_price) - 1

    return_condition = six_month_return > 0

    return ma_condition and return_condition

# %%
def market_regime_flag(
    data,
    as_of_date,
    ma_window=200
):
    data = data.copy()
    data['Date'] = pd.to_datetime(data['Date'])

    # Use only data up to the evaluation date
    data = data[data['Date'] <= as_of_date]

    # Safeguard
    if len(data) < ma_window:
        return None  # or 'UNKNOWN'

    # Moving average
    data['MA'] = data['Close'].rolling(window=ma_window).mean()

    latest_close = data.iloc[-1]['Close']
    latest_ma = data.iloc[-1]['MA']

    return 'BEAR' if latest_close < latest_ma else 'BULL'

# %% [markdown]
# Scoring ETFs

# %%
scoring = pd.DataFrame(index = etf_metric[etf_metric['Universe Eligibility']&etf_metric['Portfolio Eligibility']].index)
scoring
# Out:
# Empty DataFrame
# Columns: []
# Index: [TATSILV, SILVERBETA, SILVERIETF, SILVERBEES, SILVER, SILVER1, GOLDETF, TATAGOLD, GOLDIETF, GOLDBEES, SETFGOLD, HDFCGOLD, GOLD1, PSUBNKBEES, CPSEETF, ICICIB22, BANKBEES, SETFNIFBK, ITBEES, JUNIORBEES, NIFTYBEES, NIFTYIETF, NIFTYETF, SETFNIF50, LIQUID1, LIQUIDCASE, LIQUIDBEES, MON100]

# %%
for ticker in scoring.index:

  data = pd.read_excel(file_path,sheet_name = ticker)

  data['daily_ret'] = data['Close'].pct_change()

  latest_close = data.iloc[-1]['Close']

    # RETURNS
  lookbacks = {
      '3M Return': 63,
      '6M Return': 126,
      '12M Return': 252
  }

  for name, days in lookbacks.items():
      past_price = data.iloc[-days]['Close']
      scoring.loc[ticker,name] = (latest_close / past_price) - 1

    # 3M VOLATILITY
  scoring.loc[ticker,'3M Volatility'] = (
      data['daily_ret'].iloc[-63:].std() * np.sqrt(252)
  )

# %%
scoring
# Out:
#             3M Return  6M Return  12M Return  3M Volatility
# TATSILV      1.130314   1.754054    2.408027       0.636415
# SILVERBETA   1.019862   1.587100    2.203888       0.612030
# SILVERIETF   1.002868   1.575744    2.187697       0.638423
# SILVERBEES   1.047017   1.710056    2.255085       0.623683
# SILVER       1.047003   1.716452    2.276281       0.656663
# SILVER1      1.010299   1.588920    2.196992       0.618950
# GOLDETF      0.324520   0.613507    0.957892       0.371818
# TATAGOLD     0.346712   0.640999    0.983648       0.418950
# GOLDIETF     0.358700   0.651135    1.000000       0.368523
# GOLDBEES     0.313828   0.600000    0.932213       0.397478
# SETFGOLD     0.326461   0.616497    0.949128       0.382050
# HDFCGOLD     0.326389   0.612735    0.952149       0.390663
# GOLD1        0.295283   0.579298    0.909478       0.376714
# PSUBNKBEES   0.082257   0.327522    0.445291       0.186077
# CPSEETF      0.054333   0.095137    0.194671       0.173512
# ICICIB22     0.043508   0.121919    0.197895       0.129187
# BANKBEES     0.030856   0.073205    0.221420       0.081735
# SETFNIFBK    0.032835   0.073904    0.223314       0.079572
# ITBEES       0.063118   0.084842   -0.106329       0.171500
# JUNIORBEES  -0.032848   0.025886    0.098198       0.126076
# NIFTYBEES   -0.009876   0.033820    0.105444       0.075308
# NIFTYIETF   -0.019956   0.024120    0.110795       0.078422
# NIFTYETF    -0.020535   0.026162    0.110264       0.078890
# SETFNIF50   -0.009279   0.034405    0.106898       0.074194
# LIQUID1      0.013054   0.026522    0.056022       0.001898
# LIQUIDCASE   0.012687   0.026073    0.054925       0.002077
# LIQUIDBEES   0.000000   0.000010    0.000000       0.000103
# MON100      -0.044905   0.150384    0.114355       0.151649

# %%
nifty_df = pd.read_excel(file_path, sheet_name="NIFTY 50")
nifty_df.columns = nifty_df.columns.str.lower()

nifty_6m_return = nifty_df['close'].pct_change(126).iloc[-1]
print(nifty_6m_return)
# Out:
# 0.025920853367367824

# %%
# Momentum Rank
scoring['Rank 6M']  = scoring['6M Return'].rank(ascending=False)
scoring['Rank 3M']  = scoring['3M Return'].rank(ascending=False)
scoring['Rank 12M'] = scoring['12M Return'].rank(ascending=False)

scoring['Momentum'] = (
    0.4 * scoring['Rank 6M'] +
    0.3 * scoring['Rank 3M'] +
    0.3 * scoring['Rank 12M']
)

scoring['Momentum Rank'] = scoring['Momentum'].rank(ascending = False)

# Relative Strength Rank
scoring['RS Raw'] = scoring['6M Return'] - nifty_6m_return

scoring['RS Rank'] = scoring['RS Raw'].rank(ascending=False)

# Risk Rank
scoring['Risk Rank'] = scoring['3M Volatility'].rank(ascending=True)

scoring.head()
# Out:
#             3M Return  6M Return  12M Return  3M Volatility  Rank 6M  Rank 3M  \
# TATSILV      1.130314   1.754054    2.408027       0.636415      1.0      1.0
# SILVERBETA   1.019862   1.587100    2.203888       0.612030      5.0      4.0
# SILVERIETF   1.002868   1.575744    2.187697       0.638423      6.0      6.0
# SILVERBEES   1.047017   1.710056    2.255085       0.623683      3.0      2.0
# SILVER       1.047003   1.716452    2.276281       0.656663      2.0      3.0
#
#             Rank 12M  Momentum  Momentum Rank    RS Raw  RS Rank  Risk Rank
# TATSILV          1.0       1.0            1.0  1.728133      1.0       26.0
# SILVERBETA       4.0       4.4            4.0  1.561179      5.0       23.0
# SILVERIETF       6.0       6.0            6.0  1.549823      6.0       27.0
# SILVERBEES       3.0       2.7            3.0  1.684135      3.0       25.0
# SILVER           2.0       2.3            2.0  1.690531      2.0       28.0

# %%
# Final Score
scoring['Final Score'] = (
    0.6  * scoring['Momentum Rank'] +
    0.25 * scoring['RS Rank'] +
    0.15 * scoring['Risk Rank']
)
scoring['Final Rank'] = scoring['Final Score'].rank()
scoring.head()
# Out:
#             3M Return  6M Return  12M Return  3M Volatility  Rank 6M  Rank 3M  \
# TATSILV      1.130314   1.754054    2.408027       0.636415      1.0      1.0
# SILVERBETA   1.019862   1.587100    2.203888       0.612030      5.0      4.0
# SILVERIETF   1.002868   1.575744    2.187697       0.638423      6.0      6.0
# SILVERBEES   1.047017   1.710056    2.255085       0.623683      3.0      2.0
# SILVER       1.047003   1.716452    2.276281       0.656663      2.0      3.0
#
#             Rank 12M  Momentum  Momentum Rank    RS Raw  RS Rank  Risk Rank  \
# TATSILV          1.0       1.0            1.0  1.728133      1.0       26.0
# SILVERBETA       4.0       4.4            4.0  1.561179      5.0       23.0
# SILVERIETF       6.0       6.0            6.0  1.549823      6.0       27.0
# SILVERBEES       3.0       2.7            3.0  1.684135      3.0       25.0
# SILVER           2.0       2.3            2.0  1.690531      2.0       28.0
#
#             Final Score  Final Rank
# TATSILV            4.75         1.0
# SILVERBETA         7.10         4.0
# SILVERIETF         9.15         7.0
# SILVERBEES         6.30         3.0
# SILVER             5.90         2.0

# %%
scoring['Final Rank'].rank()
scoring.sort_values(by = 'Final Rank')
# Out:
#             3M Return  6M Return  12M Return  3M Volatility  Rank 6M  Rank 3M  \
# PSUBNKBEES      14.0      14.0           14.0  0.301602     14.0       15.0
# ICICIB22        17.0      16.6           15.0  0.095999     16.0       11.0
# CPSEETF         18.0      17.0           16.0  0.069216     17.0       14.0
# SETFNIFBK       15.0      17.5           17.0  0.047983     19.0        8.0
# BANKBEES        16.0      18.5           18.0  0.047284     20.0        9.0
# MON100          19.0      20.1           19.5  0.124463     15.0       12.0
# ITBEES          28.0      20.1           19.5  0.058921     18.0       13.0
# SETFNIF50       22.0      21.9           21.0  0.008484     21.0        4.0
# LIQUID1         25.0      22.7           22.0  0.000601     23.0        2.0
# NIFTYBEES       23.0      22.9           23.0  0.007899     22.0        5.0
# NIFTYETF        21.0      23.7           24.0  0.000241     24.0        7.0
# LIQUIDCASE      26.0      24.1           25.0  0.000153     25.0        3.0
# NIFTYIETF       20.0      24.3           26.0 -0.001801     27.0        6.0
# LIQUIDBEES      27.0      25.9           28.0 -0.025911     28.0        1.0
# JUNIORBEES      24.0      25.7           27.0 -0.000035     26.0       10.0
#
#             Final Score  Final Rank
# TATSILV            4.75         1.0
# SILVER             5.90         2.0
# SILVERBEES         6.30         3.0
# SILVERBETA         7.10         4.0
# SILVER1            7.60         5.0
# GOLDIETF           8.35         6.0
# SILVERIETF         9.15         7.0
# TATAGOLD          10.10         8.0
# SETFGOLD          10.50         9.0
# GOLDETF           11.05        10.0
# HDFCGOLD          12.35        11.0
# GOLDBEES          13.35        12.0
# GOLD1             13.75        13.0
# PSUBNKBEES        14.15        14.0
# ICICIB22          14.65        15.0
# CPSEETF           15.95        16.0
# SETFNIFBK         16.15        17.0
# BANKBEES          17.15        18.0
# MON100            17.25        19.0
# ITBEES            18.15        20.0
# SETFNIF50         18.45        21.0
# LIQUID1           19.25        22.0
# NIFTYBEES         20.05        23.0
# NIFTYETF          21.45        24.0
# LIQUIDCASE        21.70        25.0
# NIFTYIETF         23.25        26.0
# LIQUIDBEES        23.95        27.0
# JUNIORBEES        24.20        28.0

# %% [markdown]
# **Backtesting**

# %%
# Read all sheets
xls = pd.ExcelFile(file_path)

etf_data = {}
for sheet in xls.sheet_names:
    df = pd.read_excel(xls, sheet_name=sheet)
    df['Date'] = pd.to_datetime(df['Date'])
    df = df.sort_values('Date')
    etf_data[sheet] = df

# %%
etf_data
# Out:
# {'NIFTY 50':            Date     Adj Close         Close          High           Low  \
#  0    2021-01-27  13967.500000  13967.500000  14237.950195  13929.299805
#  1    2021-01-28  13817.549805  13817.549805  13898.250000  13713.250000
#  2    2021-01-29  13634.599609  13634.599609  13966.849609  13596.750000
#  3    2021-02-01  14281.200195  14281.200195  14336.349609  13661.750000
#  4    2021-02-02  14647.849609  14647.849609  14731.700195  14469.150391
#  ...         ...           ...           ...           ...           ...
#  1234 2026-01-23  25048.650391  25048.650391  25347.949219  25025.300781
#  1235 2026-01-27           NaN  25175.400391  25246.650391  24932.550781
#  1236 2026-01-28           NaN  25342.750000  25372.099609  25187.650391
#  1237 2026-01-29           NaN  25418.900391  25458.150391  25159.800781
#  1238 2026-01-30           NaN  25320.650391  25370.699219  25213.650391
#
#                Open  Volume
#  0     14237.950195  660700
#  1     13810.400391  637900
#  2     13946.599609  753200
#  3     13758.599609  870500
#  4     14481.099609  915000
#  ...            ...     ...
#  1234  25344.599609  393900
#  1235  25063.349609  618700
#  1236  25258.849609  574900
#  1237  25345.000000  582400
#  1238  25247.550781       0
#
#  [1239 rows x 7 columns],
#  'TATSILV':           Date  Adj Close      Close       High        Low       Open  \
#  0   2024-01-17   8.080000   8.080000   8.400000   7.000000   7.000000
#  1   2024-01-19   7.110000   7.110000   8.000000   7.050000   7.130000
#  2   2024-01-23   7.020000   7.020000   7.190000   6.980000   7.100000
#  3   2024-01-24   7.070000   7.070000   7.190000   7.000000   7.190000
#  4   2024-01-25   7.100000   7.100000   7.180000   7.050000   7.080000
#  ..         ...        ...        ...        ...        ...        ...
#  494 2026-01-23  29.620001  29.620001  33.000000  29.100000  30.260000
#  495 2026-01-27        NaN  32.520000  32.980000  31.000000  32.000000
#  496 2026-01-28        NaN  33.220001  34.070000  32.930000  33.110001
#  497 2026-01-29        NaN  34.939999  35.099998  34.009998  34.009998
#  498 2026-01-30        NaN  30.570000  33.939999  29.900000  33.299999
#
#          Volume
#  0       680483
#  1     31148770
#  2       601696
#  3       209744
#  4       161560
#  ..         ...
#  494  688470900
#  495  750857700
#  496  639565500
#  497  475472400
#  498  883502587
#
#  [499 rows x 7 columns],
#  'HDFCSILVER':           Date   Adj Close       Close        High         Low        Open  \
#  0   2024-03-26   72.779999   72.779999   73.800003   72.180000   73.800003
#  1   2024-03-27   72.349998   72.349998   72.699997   72.099998   72.699997
#  2   2024-03-28   72.419998   72.419998   72.839996   72.260002   72.680000
#  3   2024-04-01   73.830002   73.830002   74.419998   72.820000   74.419998
#  4   2024-04-02   74.570000   74.570000   74.690002   73.860001   73.900002
#  ..         ...         ...         ...         ...         ...         ...
#  449 2026-01-23  294.070007  294.070007  311.500000  287.649994  287.649994
#  450 2026-01-27         NaN  322.649994  329.399994  308.450012  311.709991
#  451 2026-01-28         NaN  335.899994  340.000000  324.200012  324.200012
#  452 2026-01-29         NaN  355.420013  359.000000  344.000000  344.000000
#  453 2026-01-30         NaN  297.239990  344.000000  285.000000  344.000000
#
#         Volume
#  0      238930
#  1      149652
#  2       72244
#  3      380923
#  4      380708
#  ..        ...
#  449  17624700
#  450  23506500
#  451  20542440
#  452  16571270
#  453  42494473
#
#  [454 rows x 7 columns],
#  'SILVERAG':           Date   Adj Close       Close        High         Low        Open  \
#  0   2023-06-15   71.379997   71.379997   74.449997   71.209999   72.610001
#  1   2023-06-16   72.209999   72.209999   77.830002   71.550003   74.970001
#  2   2023-06-19   72.839996   72.839996   72.989998   71.010002   72.209999
#  3   2023-06-20   72.199997   72.199997   72.750000   71.610001   72.610001
#  4   2023-06-21   70.000000   70.000000   71.110001   69.550003   71.110001
#  ..         ...         ...         ...         ...         ...         ...
#  627 2026-01-23  298.059998  298.059998  312.380005  284.609985  284.609985
#  628 2026-01-27         NaN  326.130005  330.000000  290.600006  290.600006
#  629 2026-01-28         NaN  341.320007  348.700012  331.000000  348.700012
#  630 2026-01-29         NaN  362.269989  380.000000  354.309998  380.000000
#  631 2026-01-30         NaN  308.630005  360.950012  301.000000  360.950012
#
#        Volume
#  0       5139
#  1       4669
#  2       1980
#  3       2024
#  4      14838
#  ..       ...
#  627  1334977
#  628  1939724
#  629  1572185
#  630  2243129
#  631  3411705
#
#  [632 rows x 7 columns],
#  'SILVERBETA':           Date   Adj Close       Close        High         Low        Open  \
#  0   2023
        "SMALLCAP", "SMALL250"
    ],

    # ---- Factor ETFs ----
    "FACTOR": [
        "MOMENTUM", "LOWVOL", "QUALITY", "ALPHA",
        "NV20", "QUAL30IETF"
    ],

    # ---- Liquid / Debt ----
    "DEBT_LIQUID": [
        "LIQUID", "LIQUIDBEES", "LIQUIDETF",
        "GILT", "GSEC", "SDL"
    ],

    # ---- Thematic / Others ----
    "THEMATIC": [
        "DEFENCE", "PHARMA", "ENERGY", "AUTO", "INFRA"
    ]
}

# %%
def get_exposure(ticker):
    """
    Returns exposure bucket for a given ETF ticker
    """

    ticker = ticker.upper()

    for exposure, tickers in EXPOSURE_MAP.items():
        if any(ticker.startswith(t) for t in tickers):
            return exposure

    return "OTHER"

# %%
def build_exposure_dataframe(tickers):
    """
    Creates a dataframe mapping ETF -> exposure bucket
    """

    data = []

    for t in tickers:
        data.append({
            "Ticker": t,
            "Exposure": get_exposure(t)
        })

    return pd.DataFrame(data)

# %%
exposure_map = build_exposure_dataframe(tickers)

# %%
exposure_map
# Out:
#          Ticker      Exposure
# 0      NIFTY 50  BROAD_MARKET
# 1       TATSILV        SILVER
# 2    HDFCSILVER        SILVER
# 3      SILVERAG        SILVER
# 4    SILVERBETA        SILVER
# ..          ...           ...
# 303        CONS         OTHER
# 304   MASPTOP50         OTHER
# 305     LOWVOL1        FACTOR
# 306     FINIETF       BANKING
# 307  SNXT50BETA         OTHER
#
# [308 rows x 2 columns]

# %%
# Costs associated

STT_RATE = 0.001
EXCHANGE_CHARGES = 0.0000345
SEBI_CHARGES = 0.0000001
STAMP = 0.00015
GST_RATE = 0.18

# %%
def transaction_cost(buy_turnover, sell_turnover):
    """
    Calculates total transaction cost for one portfolio rebalance
    (Indian ETFs – delivery).

    Parameters
    ----------
    buy_turnover : float
        Total value of BUY trades (₹)
    sell_turnover : float
        Total value of SELL trades (₹)

    Returns
    -------
    float
        Total transaction cost (₹)
    """

    total_turnover = buy_turnover + sell_turnover

    # ---- Charges ----
    stt = STT_RATE * total_turnover                 # STT on buy + sell
    exchange = EXCHANGE_CHARGES * total_turnover    # Exchange charges
    sebi = SEBI_CHARGES * total_turnover            # SEBI charges
    stamp = STAMP * buy_turnover                    # Stamp duty (buy-side only)

    gst = GST_RATE * (exchange + sebi)              # GST only on services

    total_cost = stt + exchange + sebi + stamp + gst

    return total_cost

# %%
def prepare_etf(df):
    df = df.copy()
    df['200MA'] = df['Close'].rolling(200).mean()
    df['3M_ret'] = df['Close'].pct_change(63)
    df['6M_ret'] = df['Close'].pct_change(126)
    df['12M_ret'] = df['Close'].pct_change(252)
    df['3M_vol'] = df['Close'].pct_change().rolling(63).std()
    return df

for k in etf_data:
    etf_data[k] = prepare_etf(etf_data[k])

# %%
etf_data
# Out:
# {'NIFTY 50':            Date     Adj Close         Close          High           Low  \
#  0    2021-01-27  13967.500000  13967.500000  14237.950195  13929.299805
#  1    2021-01-28  13817.549805  13817.549805  13898.250000  13713.250000
MA    3M_ret    6M_ret   12M_ret    3M_vol
#  0         NaN       NaN       NaN       NaN       NaN
#  1         NaN       NaN       NaN       NaN       NaN
#  2         NaN       NaN       NaN       NaN       NaN
#  3         NaN       NaN       NaN       NaN       NaN
#  4         NaN       NaN       NaN       NaN       NaN
#  ..        ...       ...       ...       ...       ...
#  802  30.96730 -0.049579 -0.024952 -0.012634  0.006982
#  803  30.98495 -0.036095 -0.021351 -0.007113  0.007020
#  804  31.00790 -0.039314 -0.010286  0.030110  0.006982
#  805  31.02785 -0.036050 -0.003242  0.032226  0.006963
#  806  31.04825 -0.046221  0.001312  0.005267  0.006985
#
#  [807 rows x 12 columns],
#  'EGOLD':           Date   Adj Close       Close        High         Low        Open  \
#  0   2023-11-10   65.000000   65.000000   66.000000   61.950001   64.500000
#  1   2023-11-13   63.549999   63.549999   74.199997   61.799999   71.750000
#  2   2023-11-15   63.650002   63.650002   65.199997   61.400002   65.199997
#  3   2023-11-16   62.299999   62.299999   65.250000   61.900002   65.250000
#  4   2023-11-17   63.250000   63.250000   64.050003   62.549999   63.950001
#  ..         ...         ...         ...         ...         ...         ...
#  539 2026-01-23  154.300003  154.300003  159.899994  152.350006  154.199997
#  540 2026-01-27         NaN  158.550003  162.750000  156.050003  158.149994
#  541 2026-01-28         NaN  164.100006  164.750000  159.649994  162.600006
#  542 2026-01-29         NaN  176.399994  184.949997  168.300003  174.000000
#  543 2026-01-30         NaN  165.800003  172.250000  159.250000  169.800003
#
#        Volume      200MA    3M_ret    6M_ret   12M_ret    3M_vol
#  0     240800        NaN       NaN       NaN       NaN       NaN
#  1      10002        NaN       NaN       NaN       NaN       NaN
#  2       3712        NaN       NaN       NaN       NaN       NaN
#  3     887617        NaN       NaN       NaN       NaN       NaN
#  4     104247        NaN       NaN       NaN       NaN       NaN
#  ..       ...        ...       ...       ...       ...       ...
#  539   144785  111.62825  0.258051  0.539920  0.904938  0.019692
#  540  1245522  111.96675  0.304401  0.562069  0.959827  0.019846
#  541  1680885  112.34100  0.353960  0.647590  1.018450  0.020192
#  542   320160  112.77850  0.539267  0.776435  1.152532  0.020621
#  543   339891  113.15325  0.370814  0.673058  1.031863  0.021376
#
#  [544 rows x 12 columns],
#  'GROWWN200':           Date  Adj Close  Close   High    Low   Open    Volume     200MA  \
#  0   2025-02-28       9.80   9.80  10.20   9.58  10.20  11157640       NaN
#  1   2025-03-03       9.82   9.82  11.60   9.07  10.00   6266019       NaN
#  2   2025-03-04       9.80   9.80  10.50   9.59  10.05    392425       NaN
#  3   2025-03-05      10.29  10.29  11.00   9.15  10.00    424717       NaN
#  4   2025-03-06      10.02  10.02  10.47   9.90  10.24    655884       NaN
#  ..         ...        ...    ...    ...    ...    ...       ...       ...
#  222 2026-01-23      11.21  11.21  11.43  11.20  11.35     50393  11.31650
#  223 2026-01-27        NaN  11.33  11.69  10.92  10.92    108113  11.32225
#  224 2026-01-28        NaN  11.40  11.48  11.29  11.38    122431  11.32455
#  225 2026-01-29        NaN  11.44  11.51  11.30  11.45    227547  11.33130
#  226 2026-01-30        NaN  11.36  11.52  10.76  10.77    169654  11.33815
#
#         3M_ret    6M_ret  12M_ret    3M_vol
#  0         NaN       NaN      NaN       NaN
#  1         NaN       NaN      NaN       NaN
#  2         NaN       NaN      NaN       NaN
#  3         NaN       NaN      NaN       NaN
#  4         NaN       NaN      NaN       NaN
#  ..        ...       ...      ...       ...
#  222 -0.039417 -0.011464      NaN  0.006148
#  223 -0.024117 -0.000882      NaN  0.006282
#  224 -0.023973  0.009743      NaN  0.006285
#  225 -0.019709  0.018700      NaN  0.006303
#  226 -0.034014  0.018834      NaN  0.006274
#
#  [227 rows x 12 columns],
#  'METALIETF':           Date  Adj Close  Close   High    Low   Open    Volume    200MA  \
#  0   2024-08-20       9.21   9.21   9.64   8.98   9.64   1643702      NaN
#  1   2024-08-21       9.29   9.29   9.42   9.20   9.35   3095221      NaN
#  2   2024-08-22       9.35   9.35   9.44   9.26   9.44   2599090      NaN
#  3   2024-08-23       9.30   9.30   9.50   9.28   9.44   2802261      NaN
#  4   2024-08-26       9.51   9.51   9.53   9.29   9.34   3626199      NaN
#  ..         ...        ...    ...    ...    ...    ...       ...      ...
#  353 2026-01-23      11.52  11.52  11.95  11.50  11.89  25899720  9.81745
#  354 2026-01-27        NaN  11.89  12.08  11.53  11.80  31115900  9.83460
#  355 2026-01-28        NaN  12.18  12.65  11.89  12.18  67211620  9.85600
#  356 2026-01-29        NaN  12.56  12.69  12.06  12.48  84601870  9.87890
#  357 2026-01-30        NaN  11.85  12.53  11.80  12.53  74109909  9.89885
#
#         3M_ret    6M_ret   12M_ret    3M_vol
#  0         NaN       NaN       NaN       NaN
#  1         NaN       NaN       NaN       NaN
#  2         NaN       NaN       NaN       NaN
#  3         NaN       NaN       NaN       NaN
#  4         NaN       NaN       NaN       NaN
#  ..        ...       ...       ...       ...
#  353  0.120623  0.207547  0.348946  0.011881
#  354  0.142171  0.241127  0.380952  0.012407
#  355  0.156695  0.271399  0.422897  0.012667
#  356  0.178236  0.331919  0.481132  0.013120
#  357  0.094183  0.272825  0.389215  0.014984
#
#  [358 rows x 12 columns],
#  'TWCGOLDETF':          Date   Adj Close       Close        High         Low        Open  \
#  0  2026-01-02  131.550003  131.550003  134.240005  130.429993  134.240005
#  1  2026-01-05  137.160004  137.160004  137.330002  132.509995  134.830002
#  2  2026-01-06  137.520004  137.520004  139.500000  137.000000  139.500000
#  3  2026-01-07  136.979996  136.979996  139.990005  134.000000  137.520004
#  4  2026-01-08  135.229996  135.229996  136.809998  134.339996  134.339996
#  5  2026-01-09  137.500000  137.500000  140.000000  133.570007  135.240005
#  6  2026-01-12  140.910004  140.910004  141.000000  139.600006  139.800003
#  7  2026-01-13  140.759995  140.759995  141.199997  139.750000  139.750000
#  8  2026-01-14  142.970001  142.970001  143.000000  141.800003  141.800003
#  9  2026-01-16  142.029999  142.029999  147.000000  140.110001  140.110001
#  10 2026-01-19  144.440002  144.440002  145.389999  142.100006  142.460007
#  11 2026-01-20  150.869995  150.869995  164.000000  143.589996  143.720001
#  12 2026-01-21  157.029999  157.029999  163.990005  153.100006  157.699997
#  13 2026-01-22  150.440002  150.440002  156.500000  130.699997  156.500000
#  14 2026-01-23  150.789993  150.789993  156.000000  148.300003  150.440002
#  15 2026-01-27         NaN  156.889999  158.000000  152.000000  158.000000
#  23 2026-01-16  141.960007  141.960007  143.509995  140.500000  143.500000
#  24 2026-01-19  145.000000  145.000000  148.679993  141.960007  141.960007
#  25 2026-01-20  150.300003  150.300003  153.779999  145.199997  145.199997
#  26 2026-01-21  159.690002  159.690002  171.919998  150.300003  155.000000
#  27 2026-01-22  150.360001  150.360001  159.990005  143.000000  159.990005
#  28 2026-01-23  152.880005  152.880005  159.300003  151.300003  152.699997
#  29 2026-01-27         NaN  158.589996  159.500000  154.410004  155.949997
#  30 2026-01-28         NaN  164.279999  166.600006  155.000000  162.550003
#  31 2026-01-29         NaN  177.580002  180.160004  165.000000  165.000000
#  32 2026-01-30         NaN  164.460007  175.979996  155.000000  170.399994
#
#      Volume  200MA  3M_ret  6M_ret  12M_ret  3M_vol
#  0     8662    NaN     NaN     NaN      NaN     NaN
#  1     7370    NaN     NaN     NaN      NaN     NaN
#  2     3432    NaN     NaN     NaN      NaN     NaN
#  3     6016    NaN     NaN     NaN      NaN     NaN
#  4     7796    NaN     NaN     NaN      NaN     NaN
#  5      961    NaN     NaN     NaN      NaN     NaN
#  6    25569    NaN     NaN     NaN      NaN     NaN
#  7    23454    NaN     NaN     NaN      NaN     NaN
#  8    20491    NaN     NaN     NaN      NaN     NaN
#  9     7210    NaN     NaN     NaN      NaN     NaN
#  10    6550    NaN     NaN     NaN      NaN     NaN
#  11    2925    NaN     NaN     NaN      NaN     NaN
#  12    3285    NaN     NaN     NaN      NaN     NaN
#  13    2332    NaN     NaN     NaN      NaN     NaN
#  14   15317    NaN     NaN     NaN      NaN     NaN
#  15   15664    NaN     NaN     NaN      NaN     NaN
#  16  113657    NaN     NaN     NaN      NaN     NaN
# ...
#  ...         ...         ...         ...         ...         ...         ...
#  1114 2026-01-26  119.120003  119.120003  119.120003  119.120003  119.120003
#  1115 2026-01-27         NaN  117.870003  121.980003  116.900002  119.709999
#  1116 2026-01-28         NaN  118.120003  121.000000  116.699997  117.860001
#  1117 2026-01-29         NaN  117.519997  122.000000  116.000000  117.800003
#  1118 2026-01-30         NaN  118.099998  120.900002  116.930000  117.510002
#
#        Volume       200MA    3M_ret    6M_ret   12M_ret    3M_vol
#  0          0         NaN       NaN       NaN       NaN       NaN
#  1      11726         NaN       NaN       NaN       NaN       NaN
#  2       3705         NaN       NaN       NaN       NaN       NaN
#  3       9575         NaN       NaN       NaN       NaN       NaN
#  4       7828         NaN       NaN       NaN       NaN       NaN
#  ...      ...         ...       ...       ...       ...       ...
#  1114       0  122.824246 -0.080367 -0.006174  0.076840  0.005403
#  1115   17710  122.864897 -0.082652 -0.011821  0.055804  0.005461
#  1116   19709  122.899847 -0.076899 -0.015338  0.061467  0.005466
#  1117   26752  122.921646 -0.081803 -0.020258  0.068849  0.005484
#  1118   29352  122.943546 -0.073144 -0.022351  0.070619  0.005526
#
#  [1119 rows x 12 columns],
#  'QUALITY30':           Date  Adj Close      Close       High        Low       Open  Volume  \
#  0   2025-07-18  20.900000  20.900000  21.150000  20.780001  20.820000    9872
#  1   2025-07-21  20.959999  20.959999  21.000000  20.719999  20.900000    6065
#  2   2025-07-22  20.809999  20.809999  20.959999  20.730000  20.959999    7769
#  3   2025-07-23  20.799999  20.799999  21.250000  20.730000  21.250000    3588
#  4   2025-07-24  20.900000  20.900000  21.250000  20.610001  20.780001   13586
#  ..         ...        ...        ...        ...        ...        ...     ...
#  128 2026-01-23  21.299999  21.299999  21.700001  21.000000  21.270000    1643
#  129 2026-01-27        NaN  21.110001  21.889999  20.900000  21.730000   13807
#  130 2026-01-28        NaN  21.440001  21.600000  20.580000  20.580000    4182
#  131 2026-01-29        NaN  21.260000  22.030001  21.010000  22.030001    9547
#  132 2026-01-30        NaN  21.469999  21.809999  20.980000  20.980000     777
#
#       200MA    3M_ret    6M_ret  12M_ret    3M_vol
#  0      NaN       NaN       NaN      NaN       NaN
#  1      NaN       NaN       NaN      NaN       NaN
#  2      NaN       NaN       NaN      NaN       NaN
#  3      NaN       NaN       NaN      NaN       NaN
#  4      NaN       NaN       NaN      NaN       NaN
#  ..     ...       ...       ...      ...       ...
#  128    NaN -0.002342  0.023546      NaN  0.006365
#  129    NaN -0.005652  0.014904      NaN  0.006426
#  130    NaN  0.002806  0.025837      NaN  0.006665
#  131    NaN  0.001885  0.019664      NaN  0.006683
#  132    NaN  0.007036  0.062345      NaN  0.006772
#
#  [133 rows x 12 columns],
#  'AXISCETF':            Date   Adj Close       Close        High         Low        Open  \
#  0    2021-09-23   74.449997   74.449997   81.000000   72.000000   75.000000
#  1    2021-09-24   72.559998   72.559998   77.889999   72.500000   72.949997
#  2    2021-09-27   72.300003   72.300003   74.730003   71.059998   74.730003
#  3    2021-09-28   71.290001   71.290001   73.099998   71.000000   73.099998
#  4    2021-09-29   70.430000   70.430000   72.949997   69.449997   72.949997
#  ...         ...         ...         ...         ...         ...         ...
#  1074 2026-01-26  118.620003  118.620003  118.620003  118.620003  118.620003
#  1075 2026-01-27         NaN  117.489998  119.209999  116.239998  119.209999
#  1076 2026-01-28         NaN  117.610001  118.070000  116.239998  118.070000
#  1077 2026-01-29         NaN  116.860001  117.080002  115.540001  117.040001
#  1078 2026-01-30         NaN  117.580002  117.949997  116.620003  117.000000
#
#        Volume      200MA    3M_ret    6M_ret   12M_ret    3M_vol
#  0      31935        NaN       NaN       NaN       NaN       NaN
#  1      17827        NaN       NaN       NaN       NaN       NaN
#  2       3465        NaN       NaN       NaN       NaN       NaN
#  3       3874        NaN       NaN       NaN       NaN       NaN
#  4       5985        NaN       NaN       NaN       NaN       NaN
#  ...      ...        ...       ...       ...       ...       ...
#  1074       0  122.56165 -0.080037 -0.017721  0.072126  0.005990
#  1075    2443  122.60635 -0.090283 -0.018791  0.059518  0.006066
#  1076    4648  122.64530 -0.085317 -0.011681  0.055935  0.006063
#  1077    2676  122.67485 -0.086746 -0.021846  0.054503  0.006080
#  1078    1602  122.69945 -0.080688 -0.021064  0.067841  0.006154
#
#  [1079 rows x 12 columns],
#  'CONS':           Date   Adj Close       Close        High         Low        Open  \
#  0   2022-07-28   74.362099   74.362099   74.362099   74.362099   74.362099
#  1   2022-08-03   76.733498   76.733498   76.733498   76.733498   76.733498
#  12    NaN     NaN     NaN      NaN     NaN
#  13    NaN     NaN     NaN      NaN     NaN
#  14    NaN     NaN     NaN      NaN     NaN
#  15    NaN     NaN     NaN      NaN     NaN
#  16    NaN     NaN     NaN      NaN     NaN
#  17    NaN     NaN     NaN      NaN     NaN
#  18    NaN     NaN     NaN      NaN     NaN
#  19    NaN     NaN     NaN      NaN     NaN
#  20    NaN     NaN     NaN      NaN     NaN
#  21    NaN     NaN     NaN      NaN     NaN
#  22    NaN     NaN     NaN      NaN     NaN
#  23    NaN     NaN     NaN      NaN     NaN
#  24    NaN     NaN     NaN      NaN     NaN
#  25    NaN     NaN     NaN      NaN     NaN
#  26    NaN     NaN     NaN      NaN     NaN
#  27    NaN     NaN     NaN      NaN     NaN
#  28    NaN     NaN     NaN      NaN     NaN
#  29    NaN     NaN     NaN      NaN     NaN
#  30    NaN     NaN     NaN      NaN     NaN
#  31    NaN     NaN     NaN      NaN     NaN  }

# %%
def market_regime(nifty_df, as_of_date):
    df = nifty_df[nifty_df['Date'] <= as_of_date]
    if len(df) < 200:
        return None
    return 'BEAR' if df.iloc[-1]['Close'] < df.iloc[-1]['200MA'] else 'BULL'

# %%
def universe_eligible(df, as_of_date):
    df = df[df['Date'] <= as_of_date]
    if len(df) < 504:
        return False
    atv = (df['Close'] * df['Volume']).mean()
    return atv >= 5e7

def portfolio_eligible(df, as_of_date):
    df = df[df['Date'] <= as_of_date]
    if len(df) < 200:
        return False
    last = df.iloc[-1]
    return (last['Close'] > last['200MA']) and (last['6M_ret'] > 0)

# %%
start_date = pd.Timestamp("2021-01-01")
end_date = etf_data['NIFTY 50']['Date'].max()

rebalance_dates = pd.date_range(start_date, end_date, freq='M')
# Out:
# /tmp/ipython-input-3679190546.py:4: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   rebalance_dates = pd.date_range(start_date, end_date, freq='M')

# %%
rebalance_dates
# Out:
# DatetimeIndex(['2021-01-31', '2021-02-28', '2021-03-31', '2021-04-30',
#                '2021-05-31', '2021-06-30', '2021-07-31', '2021-08-31',
#                '2021-09-30', '2021-10-31', '2021-11-30', '2021-12-31',
#                '2022-01-31', '2022-02-28', '2022-03-31', '2022-04-30',
#                '2022-05-31', '2022-06-30', '2022-07-31', '2022-08-31',
#                '2022-09-30', '2022-10-31', '2022-11-30', '2022-12-31',
#                '2023-01-31', '2023-02-28', '2023-03-31', '2023-04-30',
#                '2023-05-31', '2023-06-30', '2023-07-31', '2023-08-31',
#                '2023-09-30', '2023-10-31', '2023-11-30', '2023-12-31',
#                '2024-01-31', '2024-02-29', '2024-03-31', '2024-04-30',
#                '2024-05-31', '2024-06-30', '2024-07-31', '2024-08-31',
#                '2024-09-30', '2024-10-31', '2024-11-30', '2024-12-31',
#                '2025-01-31', '2025-02-28', '2025-03-31', '2025-04-30',
#                '2025-05-31', '2025-06-30', '2025-07-31', '2025-08-31',
#                '2025-09-30', '2025-10-31', '2025-11-30', '2025-12-31'],
#               dtype='datetime64[ns]', freq='ME')

# %%
def score_etfs(etf_panel, nifty_6m_ret):
    df = etf_panel.copy()

    df['Momentum'] = (
        0.4 * df['6M_ret'].rank() +
        0.3 * df['3M_ret'].rank() +
        0.3 * df['12M_ret'].rank()
    )

    df['RS'] = (df['6M_ret'] - nifty_6m_ret).rank()
    df['Risk'] = df['3M_vol'].rank(ascending=False)

    df['FinalScore'] = (
        0.6 * df['Momentum'] +
        0.25 * df['RS'] +
        0.15 * df['Risk']
    )

    return df.sort_values('FinalScore', ascending=False)

# %%
def get_eligible_panel(etf_data, as_of_date):
    rows = []

    for ticker, df in etf_data.items():
        if ticker == 'NIFTY 50':
            continue

        if universe_eligible(df, as_of_date) and portfolio_eligible(df, as_of_date):
            row = df[df['Date'] <= as_of_date].iloc[-1]
            rows.append((ticker, row))

    if not rows:
        return None

    panel = pd.DataFrame({k: v for k, v in rows}).T
    return panel

# %%
def score_and_rank(panel, nifty_6m_ret):
    panel = panel.copy()

    panel['Momentum'] = (
        0.4 * panel['6M_ret'].rank(ascending=False) +
        0.3 * panel['3M_ret'].rank(ascending=False) +
        0.3 * panel['12M_ret'].rank(ascending=False)
    )

    panel['RS'] = (panel['6M_ret'] - nifty_6m_ret).rank(ascending=False)
    panel['Risk'] = panel['3M_vol'].rank()

    panel['FinalScore'] = (
        0.6 * panel['Momentum'] +
        0.25 * panel['RS'] +
        0.15 * panel['Risk']
    )

    return panel.sort_values('FinalScore', ascending=False)

# %%
PORTFOLIO_SIZE = 5
MAX_EXPOSURE = 0.35
MAX_TURNOVER = 0.40

# %%
def get_portfolio_size(regime, risk_profile):
    """
    Returns portfolio size based on market regime and risk aversion.
    """

    BULL_LIMITS = {
        'Conservative': 5,
        'Balanced': 8,
        'Aggressive': 10
    }

    BEAR_LIMITS = {
        'Conservative': 2,
        'Balanced': 3,
        'Aggressive': 5
    }

    base_sizes = {
        "BULL": BULL_LIMITS,
        "BEAR": BEAR_LIMITS
    }

    if regime not in base_sizes:
        raise ValueError("Invalid regime")

    if risk_profile not in BULL_LIMITS:
        raise ValueError("Invalid risk profile")

    size = base_sizes[regime][risk_profile]

    return size

# %%
# def build_portfolio(ranked_df, exposure_map):
#     selected = []
#     exposure_count = {}

#     max_per_exposure = int(PORTFOLIO_SIZE * MAX_EXPOSURE)

#     for etf in ranked_df.index:
#         exp = exposure_map.get(etf, 'Other')

#         if exposure_count.get(exp, 0) >= max_per_exposure:
#             continue

#         selected.append(etf)
#         if exp != 'Other':
#           exposure_count[exp] = exposure_count.get(exp, 0) + 1

#         if len(selected) == PORTFOLIO_SIZE:
#             break

#     weight = 1 / len(selected)  #can be altered
#     return {etf: weight for etf in selected}

# %%
def build_portfolio(ranked_df, exposure_map, regime, risk_profile):
    selected = []
    used_exposures = set()

    PORTFOLIO_SIZE = get_portfolio_size(regime,risk_profile)

    for etf in ranked_df.index:
        exp = exposure_map.get(etf, 'Other')

        # Skip if exposure already taken
        if exp in used_exposures:
            continue

        selected.append(etf)
        if exp != 'Other':
          used_exposures.add(exp)

        if len(selected) == PORTFOLIO_SIZE:
            break

    # weight = 1 / len(selected)
    # return {etf: weight for etf in selected}

    scores = ranked_df.loc[selected, 'FinalScore']

    # Ensure no negative weights (important if scores can be negative)
    scores = scores - scores.min()

    weights = scores / scores.sum()

    return weights.to_dict()

# %%
def capped_turnover(old_port, new_port, portfolio_value):
    buy, sell = 0, 0

    diffs = {}

    for etf in set(old_port) | set(new_port):
        old_w = old_port.get(etf, 0)
        new_w = new_port.get(etf, 0)
        diff = new_w - old_w

        if abs(diff) < 0.05:
            continue

        diffs[etf] = diff

        if diff > 0:
            buy += diff * portfolio_value
        else:
            sell += abs(diff) * portfolio_value

    total_turnover = buy + sell
    cap = MAX_TURNOVER * portfolio_value

    # No cap needed
    if total_turnover <= cap:
        return diffs, buy, sell

    # Scale trades proportionally
    scale = cap / total_turnover
    buy *= scale
    sell *= scale

    diffs = {k: v * scale for k, v in diffs.items()}

    return diffs, buy, sell

# %%
def portfolio_return(portfolio, etf_data, prev_date, curr_date):
    """
    Computes portfolio return between two rebalance dates.
    """
    ret = 0.0

    for etf, weight in portfolio.items():
        df = etf_data[etf]

        start = df[df['Date'] <= prev_date].iloc[-1]['Close']
        end = df[df['Date'] <= curr_date].iloc[-1]['Close']

        etf_ret = (end / start) - 1
        ret += weight * etf_ret

    return ret

# %%
portfolio = {}
portfolio_value = 1_000_000
history = []
risk_profile = 'Aggressive' #can choose from Conservative, Moderate, Aggressive

prev_date = None
nifty_df = etf_data['NIFTY 50']

for dt in rebalance_dates:

    # ---- APPLY RETURNS (holding period) ----
    if prev_date is not None and portfolio:
        ret = portfolio_return(portfolio, etf_data, prev_date, dt)
        portfolio_value *= (1 + ret)

    # ---- MARKET REGIME ----
    regime = market_regime(nifty_df, dt)
    if regime is None:
        prev_date = dt
        continue

    # ---- ELIGIBLE ETFs ----
    panel = get_eligible_panel(etf_data, dt)
    if panel is None:
        prev_date = dt
        continue

    nifty_6m = nifty_df[nifty_df['Date'] <= dt].iloc[-1]['6M_ret']
    ranked = score_and_rank(panel, nifty_6m)

    # ---- TARGET PORTFOLIO ----
    new_port = build_portfolio(ranked, exposure_map, market_regime(nifty_df,dt),risk_profile)

    # ---- TURNOVER + COST ----
    diffs, buy, sell = capped_turnover(
        portfolio, new_port, portfolio_value
    )

    num_of_trades = len(diffs)
    cost = transaction_cost(buy, sell)
    portfolio_value -= cost

    # ---- UPDATE HOLDINGS ----
    portfolio = new_port
    history.append((dt, portfolio_value, num_of_trades))
    # print(ranked)
    print(portfolio)

    prev_date = dt
# Out:
# {'SETFNIFBK': 0.34285714285714297, 'BANKBEES': 0.30238095238095236, 'ITBEES': 0.22142857142857145, 'CPSEETF': 0.1333333333333333, 'PSUBNKBEES': 0.0}
# {'BANKBEES': 0.3802281368821294, 'SETFNIFBK': 0.3447401774397972, 'MON100': 0.1673003802281369, 'CPSEETF': 0.10773130544993666, 'PSUBNKBEES': 0.0}
# {'SETFNIF50': 0.27345309381237526, 'NIFTYBEES': 0.2268795741849634, 'BANKBEES': 0.17232202262142388, 'SETFNIFBK': 0.1297405189620758, 'MON100': 0.10844976713240187, 'CPSEETF': 0.06719893546240852, 'PSUBNKBEES': 0.020625415834996674, 'GOLDBEES': 0.0013306719893546545, 'SETFGOLD': 0.0}
# {'ITBEES': 0.3487819370172311, 'SETFNIF50': 0.1948900772430184, 'NIFTYBEES': 0.1532976827094474, 'GOLDBEES': 0.11348781937017231, 'BANKBEES': 0.0867498514557338, 'SETFGOLD': 0.04337492572786687, 'CPSEETF': 0.0409982174688057, 'SETFNIFBK': 0.01841948900772433, 'MON100': 0.0}
# {'JUNIORBEES': 0.25597749648382573, 'MON100': 0.2320675105485231, 'NIFTYBEES': 0.13642756680731363, 'SETFNIF50': 0.08860759493670892, 'PSUBNKBEES': 0.08860759493670892, 'HDFCSML250': 0.06469760900140654, 'LIQUID1': 0.057665260196905745, 'BANKBEES': 0.04781997187060473, 'MID150BEES': 0.028129395218002694, 'SETFNIFBK': 0.0}
# {'NIFTYETF': 0.19099099099099104, 'LIQUIDBEES': 0.14189189189189183, 'NIFTYBEES': 0.13603603603603603, 'SETFNIF50': 0.12162162162162161, 'CPSEETF': 0.11711711711711706, 'LIQUIDETF': 0.11216216216216213, 'ICICIB22': 0.09909909909909911, 'HDFCSML250': 0.06666666666666661, 'JUNIORBEES': 0.01441441441441457, 'MID150BEES': 0.0}
# {'PHARMABEES': 0.2875104777870913, 'LIQUID1': 0.17854149203688177, 'SETFNIFBK': 0.12740989103101422, 'CPSEETF': 0.12657166806370493, 'BANKBEES': 0.09681475272422468, 'HDFCSML250': 0.06077116512992464, 'JUNIORBEES': 0.05071248952221292, 'NIFTYETF': 0.041911148365465264, 'MID150BEES': 0.029756915339480394, 'NIFTYBEES': 0.0}
# {'HDFCSML250': 0.2337106148669317, 'ITBEES': 0.2113796267971857, 'JUNIORBEES': 0.1538696849189355, 'LIQUID1': 0.13031508106454567, 'MID150BEES': 0.09299479963291525, 'ICICIB22': 0.06423982869379015, 'PHARMABEES': 0.05200367084735391, 'SETFNIF50': 0.04190884062404408, 'NIFTYETF': 0.019577852554297916, 'NIFTYBEES': 0.0}
# {'JUNIORBEES': 0.2486559139784949, 'LIQUIDETF': 0.24238351254480278, 'MID150BEES': 0.20116487455197146, 'LIQUID1': 0.15098566308243733, 'PHARMABEES': 0.07213261648745514, 'SETFNIF50': 0.0389784946236559, 'NIFTYETF': 0.030465949820788457, 'MON100': 0.013440860215053644, 'NIFTYBEES': 0.0017921146953404647, 'NIFTYIETF': 0.0}

# %%
result = pd.DataFrame(history, columns=['Date', 'Portfolio','No. of Trades'])
result = result.set_index('Date')

nifty_df = pd.read_excel(file_path, sheet_name="NIFTY 50")
nifty_df["Date"] = pd.to_datetime(nifty_df["Date"])

nifty_curve = nifty_df.set_index("Date")["Close"]

# Align NIFTY to portfolio dates safely
nifty_curve = nifty_curve.reindex(
    result.index,
    method="ffill"
)

# Normalize to same starting value
nifty_curve = nifty_curve / nifty_curve.iloc[0] * result.iloc[0, 0]

comparison = pd.concat([result, nifty_curve.rename('NIFTY')], axis=1)

# %%
assert nifty_curve.isna().sum() == 0

# %%
comparison
# Out:
#                Portfolio  No. of Trades         NIFTY
# Date
# 2023-02-28  9.995237e+05              4  9.995237e+05
# 2023-03-31  9.962765e+05              3  1.002747e+06
# 2023-04-30  1.046501e+06              5  1.043484e+06
# 2023-05-31  1.083794e+06              7  1.070598e+06
# 2023-06-30  1.097827e+06              6  1.108412e+06
# 2023-07-31  1.121167e+06              1  1.141034e+06
# 2023-08-31  1.118431e+06              3  1.112152e+06
# 2023-09-30  1.130933e+06              6  1.134362e+06
# 2023-10-31  1.105609e+06              9  1.102090e+06
# 2023-11-30  1.166831e+06              8  1.162946e+06
# 2023-12-31  1.234516e+06              4  1.255265e+06
# 2024-01-31  1.218998e+06              4  1.254936e+06
# 2024-02-29  1.221903e+06              3  1.269787e+06
# 2024-03-31  1.247810e+06              5  1.289663e+06
# 2024-04-30  1.289938e+06              2  1.305718e+06
# 2024-05-31  1.337781e+06              3  1.301435e+06
# 2024-06-30  1.385747e+06              7  1.386918e+06
# 2024-07-31  1.412705e+06              7  1.441247e+06
# 2024-08-31  1.437077e+06              7  1.457695e+06
# 2024-09-30  1.464512e+06              5  1.490906e+06
# 2024-10-31  1.481353e+06              9  1.398168e+06
# 2024-11-30  1.482487e+06              7  1.393879e+06
# 2024-12-31  1.447656e+06              9  1.365789e+06
# 2025-01-31  1.454124e+06              4  1.357910e+06
# 2025-02-28  1.386396e+06              4  1.277983e+06
# 2025-03-31  1.433293e+06              5  1.358542e+06
# 2025-04-30  1.375708e+06              7  1.405610e+06
# 2025-05-31  1.393158e+06             10  1.429668e+06
# 2025-06-30  1.452606e+06              9  1.473935e+06
# 2025-07-31  1.415126e+06              5  1.430688e+06
# 2025-08-31  1.393806e+06              5  1.410962e+06
# 2025-09-30  1.451857e+06              9  1.421605e+06
# 2025-10-31  1.498627e+06             10  1.485779e+06
# 2025-11-30  1.517033e+06              9  1.513554e+06
# 2025-12-31  1.520018e+06              6  1.509317e+06

# %%
def compute_cagr(series):
    start = series.iloc[0]
    end = series.iloc[-1]
    years = (series.index[-1] - series.index[0]).days / 365.25
    return (end / start) ** (1 / years) - 1

def compute_volatility(series):
    returns = series.pct_change().dropna()
    return returns.std() * np.sqrt(252)

def compute_max_drawdown(series):
    cum_max = series.cummax()
    drawdown = (series - cum_max) / cum_max
    return drawdown.min()

def compute_sharpe(series):
    returns = series.pct_change().dropna()
    return (returns.mean() / returns.std()) * np.sqrt(252)

# %%
def summarize_performance(nav_series):
    return {
        "Final Value": nav_series.iloc[-1],
        "Total Return (%)": (nav_series.iloc[-1] / nav_series.iloc[0] - 1) * 100,
        "CAGR (%)": compute_cagr(nav_series) * 100,
        "Volatility (%)": compute_volatility(nav_series) * 100,
        "Max Drawdown (%)": compute_max_drawdown(nav_series) * 100,
        "Sharpe Ratio": compute_sharpe(nav_series)
    }

# %%
portfolio_nav = result.iloc[:, 0]   # your portfolio NAV
benchmark_nav = nifty_curve         # NIFTY ETF NAV

# %%
final_table = pd.DataFrame.from_dict(
    {
        "Portfolio": summarize_performance(portfolio_nav),
        "NIFTY ETF": summarize_performance(benchmark_nav)
    },
    orient="index"
)

final_table
# Out:
#             Final Value  Total Return (%)   CAGR (%)  Volatility (%)  \
# Portfolio  1.520018e+06         52.074276  15.910640       41.795360
# NIFTY ETF  1.509317e+06         51.003677  15.622569       51.639672
#
#            Max Drawdown (%)  Sharpe Ratio
# Portfolio         -7.202676      7.681512
# NIFTY ETF        -14.281399      6.200473

# %%
comparison.to_excel('/content/backtest.xlsx')
